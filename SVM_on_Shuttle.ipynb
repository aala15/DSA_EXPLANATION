# %%
import numpy as np
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#df.to_csv('example',index=False)

# %%
shuttle = pd.read_csv('Shuttle.csv')
shuttle_test = pd.read_csv('shuttle_tst.txt',sep =' ', names=['v1','v2','v3','v4','v5','v6','v7','v8','v9','Class'])
shuttle_train = pd.read_csv('shuttle_train.txt',sep =' ',names=['v1','v2','v3','v4','v5','v6','v7','v8','v9','Class'])

# %%
shuttle_c = pd.concat([shuttle_test,shuttle_train],axis=0,sort=False)

# %%
shuttle['Class'].value_counts()
# Out:
# 1    34108
# 4     6748
# 5     2458
# 3      132
# 2       37
# 7       11
# 6        6
# Name: Class, dtype: int64

# %%
def classDetector(x):
    if x == 1:
        return 0
    else:
        return 1

# %%
shuttle.head()
# Out:
#    v1  v2  v3  v4  v5  v6  v7  v8  v9  Class
# 0  50  21  77   0  28   0  27  48  22      2
# 1  55   0  92   0   0  26  36  92  56      4
# 2  53   0  82   0  52  -5  29  30   2      1
# 3  37   0  76   0  28  18  40  48   8      1
# 4  37   0  79   0  34 -26  43  46   2      1

# %%
shuttle_test['Class']=shuttle_test['Class'].apply(classDetector)
shuttle_train['Class']=shuttle_train['Class'].apply(classDetector)

# %%
shuttle['Class']=shuttle['Class'].apply(classDetector)

# %%
shuttle_c['Class']=shuttle_c['Class'].apply(classDetector)

# %%
shuttle_c.head()
# Out:
#    v1  v2  v3  v4  v5  v6  v7  v8  v9  Class
# 0  55   0  81   0  -6  11  25  88  64      1
# 1  56   0  96   0  52  -4  40  44   4      1
# 2  50  -1  89  -7  50   0  39  40   2      0
# 3  53   9  79   0  42  -2  25  37  12      1
# 4  55   2  82   0  54  -6  26  28   2      0

# %%
shuttle_c
# Out:
#         v1  v2   v3  v4  v5   v6  v7   v8  v9  Class
# 0       55   0   81   0  -6   11  25   88  64      1
# 1       56   0   96   0  52   -4  40   44   4      1
# 2       50  -1   89  -7  50    0  39   40   2      0
# 3       53   9   79   0  42   -2  25   37  12      1
# 4       55   2   82   0  54   -6  26   28   2      0
# 5       41   0   84   3  38   -4  43   45   2      0
# 6       37   0  100   0  36   -8  63   64   2      0
# 7       46   0   83   0  46    0  37   36   0      0
# 8       44   0   79   0  42  -17  35   37   2      0
# 9       44  -1   78   0  44    0  34   34   0      0
# 10      55   0   81   0  54  -10  25   26   2      0
# 11      56   0   95   0  52   -3  40   44   4      1
# 12      37   0  100   0  34    6  64   67   4      0
# 13      43  -3   86   2  44   14  43   42   0      0
# 14      46  -5   84   0  46    0  38   37   0      0
# 15      45   0   81   0  44    0  36   37   0      0
# 16      48   0   86   0  50   30  38   37   0      0
# 17      56   0   78   0  42   -2  22   37  14      1
# 18      56   0   77   0  18  -18  22   59  38      1
# 19      45   5   90   0  44    0  44   46   2      0
# 20      37   0   77   0 -20   27  41   98  58      0
# 21      37   0   90  -6  18    0  53   72  20      0
# 22      37  -8   77   0  20    0  40   57  16      0
# 23      50   5   95  -3  50    0  45   46   2      0
# 24      43  -2   76   0  44   15  32   32   0      0
# 25      42  -1   85  -5  42    0  44   44   0      0
# 26      55   0   97   0  46   -2  42   51   8      1
# 27      37   0   76   0  26   20  39   50  12      0
# 28      37   0   76   8  30    0  40   45   6      0
# 29      45   0  106   0  46    9  61   60   0      0
# ...    ...  ..  ...  ..  ..  ...  ..  ...  ..    ...
# 43470   50   4   88   0  50    0  38   39   2      0
# 43471   43  -4  106   0  42   -7  62   64   2      0
# 43472   45  -2   76   0  44  -11  31   32   2      0
# 43473   37   0   79   0  10  374  42   69  26      0
# 43474   37   5   79   0  34    0  42   46   4      0
# 43475   46   0   81   0  44  -14  35   37   2      0
# 43476  102   0  102  -7  72   24   1   30  30      1
# 43477   44   0   86   0  44    9  42   42   0      0
# 43478   37   0   77   2  36   -1  39   41   2      0
# 43479   37   0   78   0  36   -4  41   42   2      0
# 43480   44   0   79   0  42  -14  35   37   2      0
# 43481   55   0   82   0 -18    9  26  100  74      1
# 43482   46   4   79   0  46   19  33   32   0      0
# 43483   42  -5   99   0  42    0  58   58   0      0
# 43484   56   0   82   0 -12    1  26   95  68      1
# 43485   55   0   79   0   6    8  23   74  50      1
# 43486   49   4   87   0  50   27  38   38   0      0
# 43487  105   5  106   1  70    0   1   36  36      1
# 43488   37   0   77   0  20    2  40   56  16      0
# 43489   56   0   95   0  56    1  40   39   0      0
# 43490   45  -5   82   0  44    0  37   38   0      0
# 43491   51   0   83   0  50   -7  32   34   2      0
# 43492  105  -1  107   0  70    0   1   37  36      1
# 43493   37  -1   76   0  38    6  39   37   0      0
# 43494   45  -5   90   0  44  -26  45   46   2      0
# 43495   46   5   78   0  46    5  32   32   0      0
# 43496   37   0   79  -1  10    3  43   69  26      0
# 43497   48   0   78   3  46    0  30   32   2      0
# 43498   41   0   79   0  38  -25  38   40   2      0
# 43499   40  -3  100   0  38    0  61   62   2      0
#
# [58000 rows x 10 columns]

# %%
shuttle_c['Class'].value_counts()
# Out:
# 0    45586
# 1    12414
# Name: Class, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X = shuttle_c.drop('Class',axis=1)
y = shuttle_c['Class']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=101)

# %%
X_train2=shuttle_train.drop('Class',axis=1)
Y_train2=shuttle_train['Class']
X_test2=shuttle_test.drop('Class',axis=1)
Y_test2=shuttle_test['Class']

# %%
from sklearn.svm import SVC

# %%
#model = SVC(kernel='linear')

# %%
model.fit(X_train2,Y_train2)

# %%
predictions = model.predict(X_test2)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test2,predictions))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.99      0.98      0.99     15036
#           1       0.95      0.98      0.96      4104
#
# avg / total       0.98      0.98      0.98     19140

# %%
print(confusion_matrix(y_test2,predictions))
# Out:
# [[14807   229]
#  [  101  4003]]

# %%
coef=model.coef_.ravel()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-f2ef0609f70f> in <module>()
# ----> 1 coef=model.coef_.ravel()
#
# NameError: name 'model' is not defined

# %%
model.decision_function
# Out:
# <bound method BaseSVC.decision_function of SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)>

# %%
model.decision_function_shape
# Out:
# 'ovr'

# %%
model.coef0
# Out:
# 0.0

# %%
model.degree
# Out:
# 3

# %% [markdown]
# model.intercept_

# %%
model.support_
# Out:
# array([   58,    68,   108, ..., 38747, 38775, 38793], dtype=int32)

# %%
coe=coef=model.coef_.ravel()

# %%
coe
# Out:
# array([-1.09790193e-01, -1.92291588e-03, -1.65063928e-02, -2.82659061e-03,
#         4.96818230e-01,  3.60176738e-04, -6.59466455e-01,  7.25918401e-01,
#        -9.49188379e-02])

# %%
coefr=abs(coef.reshape(1,9))

# %%
percent=np.linspace(0,1,10)
percent
# Out:
# array([0.        , 0.11111111, 0.22222222, 0.33333333, 0.44444444,
#        0.55555556, 0.66666667, 0.77777778, 0.88888889, 1.        ])

# %%
dfCoef = pd.DataFrame(coefr,columns='v1 v2 v3 v4 v5 v6 v7 v8 v9'.split())

# %%
dfCoef
# Out:
#         v1        v2        v3        v4        v5       v6        v7  \
# 0  0.10979  0.001923  0.016506  0.002827  0.496818  0.00036  0.659466
#
#          v8        v9
# 0  0.725918  0.094919

# %%
dfCoef.columns
# Out:
# Index(['v1', 'v2', 'v3', 'v4', 'v5', 'v6', 'v7', 'v8', 'v9'], dtype='object')

# %%
tDf=dfCoef.loc[:, (dfCoef>0.5).any()]

# %%
tDf
# Out:
#          v7        v8
# 0  0.659466  0.725918

# %%
z=tDf.columns.values

# %%
zz=list(z)
zz
# Out:
# ['v7', 'v8']

# %%
def jaccard(lst1, lst2): 
    a = set(lst1).intersection(lst2)
    b = set(lst1).union(lst2)
    c = len(a)/len(b)
    return c

# %%
dfCoef.to_csv('coeffff',index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-66e55f32e390> in <module>()
# ----> 1 dfCoef.to_csv('coeffff',index=False)
#
# NameError: name 'dfCoef' is not defined

# %%
coefficiant = pd.read_csv('coeffff')

# %%
coefficiant
# Out:
#          v1        v2        v3       v4        v5        v6        v7  \
# 0  0.161464  0.002783  0.024346  0.00029  0.569491  0.000635  0.762696
#
#          v8        v9
# 0  0.834912  0.126539

# %%
def intersection(lst1, lst2): 
    return list(set(lst1) & set(lst2))

# %%
import csv
percent=np.linspace(0,1,20)
avgList=[]
for per in percent:
    tDf=coefficiant.loc[:, (coefficiant>per).any()]
    zz=list(tDf.columns.values)
    with open('manual explanation.csv', newline='\n') as csvfile:
        csv_reader=csv.reader(csvfile, delimiter='\n')
        line_count=0
        i=0
        summ = 0
        print('if threshold is {} the average distance is :'.format(per))
        for row in csv_reader:
            summ = summ + jaccard(row[0].split(','),zz)    
            avg = summ/100
        avgList.append(avg)
        print (avg)
# Out:
# if threshold is 0.0 the average distance is :
# 0.22222222222222177
# if threshold is 0.05263157894736842 the average distance is :
# 0.39999999999999925
# if threshold is 0.10526315789473684 the average distance is :
# 0.39999999999999925
# if threshold is 0.15789473684210525 the average distance is :
# 0.19999999999999962
# if threshold is 0.21052631578947367 the average distance is :
# 0.0
# if threshold is 0.2631578947368421 the average distance is :
# 0.0
# if threshold is 0.3157894736842105 the average distance is :
# 0.0
# if threshold is 0.3684210526315789 the average distance is :
# 0.0
# if threshold is 0.42105263157894735 the average distance is :
# 0.0
# if threshold is 0.47368421052631576 the average distance is :
# 0.0
# if threshold is 0.5263157894736842 the average distance is :
# 0.0
# if threshold is 0.5789473684210527 the average distance is :
# 0.0
# if threshold is 0.631578947368421 the average distance is :
# 0.0
# if threshold is 0.6842105263157894 the average distance is :
# 0.0
# if threshold is 0.7368421052631579 the average distance is :
# 0.0
# if threshold is 0.7894736842105263 the average distance is :
# 0.0
# if threshold is 0.8421052631578947 the average distance is :
# 0.0
# if threshold is 0.894736842105263 the average distance is :
# 0.0
# if threshold is 0.9473684210526315 the average distance is :
# 0.0
# if threshold is 1.0 the average distance is :
# 0.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(percent, avgList, 'r') # 'r' is the color red
plt.xlabel('Threshold')
plt.ylabel('J-Distance')
plt.title('similarity variation')
plt.show()
